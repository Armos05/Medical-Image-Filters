# %% [markdown]
# <a href="https://colab.research.google.com/github/Armos05/Medical-Image-Filters/blob/main/Basic_Deep_Learning_Image_Denoising.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt

# %%
from google.colab import files
image = files.upload()
# Out:
#      <input type="file" id="files-acef753c-3644-47cb-9380-66d2fd0dc256" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-acef753c-3644-47cb-9380-66d2fd0dc256">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving MRI_Head_Brain_Normal.jpg to MRI_Head_Brain_Normal.jpg

# %%
image = cv2.imread('MRI_Head_Brain_Normal.jpg')
image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
plt.imshow(image)

# %%
# Image to array
array = np.asarray(image)
print("The Size of the Array is", array.shape, "While its data type is", type(array))

# Array to Image
plt.imshow(array)
# Out:
# The Size of the Array is (673, 697) While its data type is <class 'numpy.ndarray'>

# %%
from PIL import Image

image = Image.open('MRI_Head_Brain_Normal.jpg')
new_image = image.resize((28, 28))
new_image = cv2.cvtColor(np.float32(new_image), cv2.COLOR_BGR2GRAY)
plt.imshow(new_image)

# %%
cv2.imwrite("Test.png", new_image)
# Out:
# True

# %%
new_image.shape
# Out:
# (28, 28)

# %%
test = cv2.imread("Test.png", 0)
test.shape
# Out:
# (28, 28)
